# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from thefuzz import fuzz
from thefuzz import process

# %% [markdown]
# # Clean up data from details page dataset

# %%
df_d=pd.read_json('bizbuysell.detail.lines.json',lines=True)
df_d['id']=df_d.s_id
df_d['src']='details'
df_d['url']=df_d['s_url']
df_d['title']=df_d['s_name']
df_d['desc']=df_d['s_desc']
df_d['local']=df_d['s_local']
df_d['region']=df_d['s_region']
df_d['location']=df_d['p_location']
df_d['title_loc']=df_d['title'].str.extract(r"in (.+) - BizBuySell")
df_d['categories']=df_d['s_breadcrumbs']
df_d['details']=df_d['p_details_text']
df_d['financials']=df_d['p_financials_text']
df_d['price']=df_d['s_price']
df_d['similar']=df_d['s_similar']

# %%
df_dd=df_d[['id','src','url','title',
            'desc','local','region','location','title_loc','categories','similar',
            'details','financials','price']]

# %%
df_dd.iloc[0]
# Out:
# id                                                    2067319.0
# src                                                     details
# url           https://www.bizbuysell.com/Business-Real-Estat...
# title         Popular Marina in Central New Jersey in Middle...
# desc          It is fully owned by a man and his wife since ...
# local                                                 Middlesex
# region                                               New Jersey
# location                                   Middlesex County, NJ
# title_loc     Central New Jersey in Middlesex County, New Je...
# categories    [Real Estate For Sale, New Jersey, Marinas and...
# similar                             [1864705, 2071534, 2057087]
# details       Location:\nMiddlesex County, NJ\nType:\nOther ...
# financials    Asking Price:\n$2,500,000\n                   ...
# price                                                 2500000.0
# Name: 0, dtype: object

# %% [markdown]
# # Clean up data from listings dataset

# %%
def proc_fin(row):
    result=''
    if pd.isna(row['asking_price'])==False:
        result+=f'Asking Price:\n{row["asking_price"]}\n'
    if pd.isna(row['cash_flow'])==False:
        result+=f'Cash Flow:\n{row["cash_flow"]}\n'        
    return result

# %%
df_l=pd.read_json('bizbuysell.list.lines.json',lines=True)
df_l['id']=df_l.s_id
df_l['src']='listings'
df_l['url']='https://www.bizbuysell.com'+df_l['s_url']
df_l['title']=df_l['s_name']
df_l['desc']=df_l['s_desc']
df_l['local']=df_l['s_local']
df_l['region']=df_l['s_region']
df_l['location']=df_l['loc']
df_l['title_loc']=df_l['title'].str.extract(r"in (.+) - BizBuySell")
df_l['categories']=df_l['s_breadcrumbs']
df_l['details']=''
df_l['financials']=df_l.apply(proc_fin,axis=1)
df_l['price']=df_d['s_price'].replace('$','').replace(',','')
df_l['similar']=[list() for x in range(len(df_l.index))]

# %%
df_ll=df_l[['id','src','url','title',
            'desc','local','region','location','title_loc','categories', 'similar',
            'details','financials','price']]

# %%
df_ll.iloc[0]
# Out:
# id                                                      1972353
# src                                                    listings
# url           https://www.bizbuysell.com/Business-Opportunit...
# title                    Turnkey Jewelry Store in the Caribbean
# desc          Almost 33 years ago, the founders of The Natur...
# local                                                      None
# region                                            Christiansted
# location                                          Christiansted
# title_loc                                                   NaN
# categories    [Businesses For Sale, Travel Businesses For Sa...
# similar                                                      []
# details
# financials                          Asking Price:\n$2,000,000\n
# price                                                 2500000.0
# Name: 0, dtype: object

# %% [markdown]
# # Combine datasets

# %%
df=pd.concat([df_dd,df_ll])

# %%
df.shape
# Out:
# (302163, 14)

# %% [markdown]
# # Enrich

# %%
df['franchise']=df.title.str.contains("franchise", case=False)
df['lease']=df.title.str.contains("lease", case=False)
df['auction']=df.title.str.contains("auction", case= False)
df['rent']=df.title.str.contains("rent", case= False)

# %%
df['_location']=df['location'].fillna(value='')
df['nationwide']=df._location.str.contains("Available Nationwide", case=False)
df['nationwide'].fillna(value=False, inplace=True)
df['multiple_locations']=df._location.str.contains("Available in Multiple Locations", case=False)
df['multiple_locations'].fillna(value=False, inplace=True)
df['relocatable']=df._location.str.contains("Relocatable", case=False)
df['relocatable'].fillna(value=False, inplace=True)

# %%
def proc_loc(row):
    result=None
    if pd.isna(row['location'])==False:
        l=str(row['location']).lower().strip()
        result= l
    elif pd.isna(row['local'])==False and pd.isna(row['region'])==False:
        l=str(row['local']).lower().strip()
        r=str(row['region']).lower().strip()
        result= f"{l}, {r}"
    elif pd.isna(row['title_loc'])==False:
        l=str(row['title_loc']).lower().strip()
        result= l
    if result !=None:
        for r in ['(relocatable)','available in']:
            result=result.replace(r,'')
        result=result.strip()
    return result
df['proc_loc'] = df.apply(proc_loc, axis=1)

# %% [markdown]
# # Get rid of franchise, lease, auction, rent

# %%
#df=df.loc[(df.franchise==False)&(df.lease==False)&(df.acution==False)&(df.rent==False)]
df=df.loc[(df.lease==False)&(df.auction==False)&(df.rent==False)]

# %%
df.shape
# Out:
# (294623, 23)

# %% [markdown]
# # Get rid of nationwide and multiple location listings

# %%
df=df.loc[(df.nationwide==False)&(df.multiple_locations==False)]

# %%
df.shape
# Out:
# (287470, 23)

# %% [markdown]
# # Get rid of duplicates by id

# %%
df=df.drop_duplicates(['id'])

# %%
df.shape
# Out:
# (38104, 23)

# %% [markdown]
# # Clean up null data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38104 entries, 0 to 263471
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  38104 non-null  float64
#  1   src                 38104 non-null  object
#  2   url                 38104 non-null  object
#  3   title               38104 non-null  object
#  4   desc                38104 non-null  object
#  5   local               33717 non-null  object
#  6   region              34014 non-null  object
#  7   location            37980 non-null  object
#  8   title_loc           37062 non-null  object
#  9   categories          38104 non-null  object
#  10  similar             38104 non-null  object
#  11  details             37952 non-null  object
#  12  financials          38104 non-null  object
#  13  price               37775 non-null  float64
#  14  franchise           38104 non-null  object
#  15  lease               38104 non-null  object
#  16  auction             38104 non-null  object
#  17  rent                38104 non-null  object
#  18  _location           38104 non-null  object
#  19  nationwide          38104 non-null  bool
#  20  multiple_locations  38104 non-null  bool
#  21  relocatable         38104 non-null  bool
#  22  proc_loc            38101 non-null  object
# dtypes: bool(3), float64(2), object(18)
# memory usage: 6.2+ MB

# %%
df=df.loc[(df.price.isna()==False) & (df.proc_loc.isna()==False)]
df['details'].fillna(value='', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37773 entries, 0 to 37743
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  37773 non-null  float64
#  1   src                 37773 non-null  object
#  2   url                 37773 non-null  object
#  3   title               37773 non-null  object
#  4   desc                37773 non-null  object
#  5   local               33439 non-null  object
#  6   region              33690 non-null  object
#  7   location            37713 non-null  object
#  8   title_loc           37060 non-null  object
#  9   categories          37773 non-null  object
#  10  similar             37773 non-null  object
#  11  details             37773 non-null  object
#  12  financials          37773 non-null  object
#  13  price               37773 non-null  float64
#  14  franchise           37773 non-null  object
#  15  lease               37773 non-null  object
#  16  auction             37773 non-null  object
#  17  rent                37773 non-null  object
#  18  _location           37773 non-null  object
#  19  nationwide          37773 non-null  bool
#  20  multiple_locations  37773 non-null  bool
#  21  relocatable         37773 non-null  bool
#  22  proc_loc            37773 non-null  object
# dtypes: bool(3), float64(2), object(18)
# memory usage: 6.2+ MB

# %% [markdown]
# # Load location data

# %%
df_loc=pd.read_pickle('../census/codes/locations.pkl')
df_loc.to_excel('locations.xlsx')

# %%
df_loc.head()
# Out:
#        FEATURE_ID     location            H3_15
# 1859        44784      arizona  8f29b6d357ae255
# 6298        83350     arkansas  8f265b41b7485a4
# 10369      165344      alabama  8f44ec7996a29b5
# 12114      201738     colorado  8f268cda8071b71
# 13216      213160  connecticut  8f2a14b9892e0e0

# %%
df_loc=df_loc.loc[df_loc['location'].str.len()>2]
loc=list(df_loc['location'].unique())
loc.sort(key = len,reverse=True)

#loc

df_f=df[:20]

# df_f["fuzz_loc"] = df_f["proc_loc"].apply(
#   lambda x: process.extract(x, loc, scorer=fuzz.ratio)
# )

df_f["fuzz_loc"] = df_f["proc_loc"].apply(
  lambda x: process.extract(x, loc,scorer=fuzz.partial_token_sort_ratio)
)

df_f
# Out:
#            id      src                                                url
# 0   2067319.0  details  https://www.bizbuysell.com/Business-Real-Estat...  \
# 1   1990890.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 3   2039720.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 4   1576680.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 5   2087638.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 6   2086340.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 7   2051958.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 8   1861169.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 9   1975813.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 10  1975814.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 11  2087263.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 12  2070330.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 14  2040365.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 15  2069655.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 17  1944298.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 18  2062874.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 19  2057058.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 20  1896070.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 21  2078111.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 22  2021451.0  details  https://www.bizbuysell.com/Business-Real-Estat...
#
#                                                 title
# 0   Popular Marina in Central New Jersey in Middle...  \
# 1   High Exposure in Mays Landing, New Jersey - Bi...
# 3   Duplex, Short term or Long term in Pinellas Co...
# 4   Major Price Reduction Rest/Tavern/ 13,000sq. f...
# 5   Business & Real Estate in Casco, Michigan - Bi...
# 6   High Grossing Atlanta Liquor Store in Fulton C...
# 7   Turnkey Restaurant Near Lake Wister State Park...
# 8   Well Established Sports Bar & Restaurant w/ Re...
# 9   Auto-Repair shop and community shopping center...
# 10  Auto-Repair shop and community shopping center...
# 11  Cannabis CUP License Approved! Warehouse and S...
# 12  Out lot Zoned Fast Casual/Drive-Thru Across Ca...
# 14  Commercial Real Estate w/Turnkey Resale Busine...
# 15  Colonial Beach Yacht Center in Colonial Beach,...
# 17  Medical Building and commercial property for s...
# 18  High Volume Country Tavern with Real Estate in...
# 19  Turn Key Commercial Building in high traffic a...
# 20  Large Restaurant with Property in Maryland in ...
# 21  Prime Retail / Professional Space. Build to Su...
# 22  Beautiful condo in busy area in Vineland, New ...
#
#                                                  desc           local
# 0   It is fully owned by a man and his wife since ...       Middlesex  \
# 1   AMAZING OPPORTUNITY! Priced to sell and ready ...    Mays Landing
# 3   Rare Largo/Seminole area duplex centrally loca...        Pinellas
# 4   Price reduced to $850. 000 MAKE AN OFFER!!!!!!...       Baltimore
# 5   • The Business and the Real Estate are For Sal...           Casco
# 6   High grossing Atlanta liquor store with limite...          Fulton
# 7   COMMERCIAL REAL ESTATE FOR SALE WELCOME TO 409...          Wister
# 8   Grand Opening after closing for few years.Owne...        Quantico
# 9   Over 30 years Community Auto Repair Mechanic s...         Fairfax
# 10  Over 30 years Community Auto Repair Mechanic s...         Fairfax
# 11  Two buildings on one lot with 1.25 acres! Sing...       Lancaster
# 12  Fast casual Drive thru out lot +-1 acre, High ...      South Bend
# 14  Commercial Property - The building, which boas...         Yankton
# 15  Colonial Beach Yacht Center (CBYC) is a full s...  Colonial Beach
# 17  Tremendous opportunity.   Medical building on ...      Georgetown
# 18  HIGH VOLUME BAR & GRILLA casual theme, moderat...         Norfolk
# 19  Commercial building available right off of Hig...           Perry
# 20  This is a large, 15,521 sf, building, sited on...     Brownsville
# 21  Rare to Market. Unique Opportunity to Own this...           Miami
# 22  Beautiful condo in busy area. Owners updated i...        Vineland
#
#            region                                  location
# 0      New Jersey                      Middlesex County, NJ  \
# 1      New Jersey        Mays Landing, NJ (Atlantic County)
# 3         Florida                       Pinellas County, FL
# 4        Maryland     Baltimore, MD (Baltimore City County)
# 5        Michigan            Casco, MI (Saint Clair County)
# 6         Georgia                         Fulton County, GA
# 7        Oklahoma               Wister, OK (LeFlore County)
# 8        Virginia      Quantico, VA (Prince William County)
# 9        Virginia                        Fairfax County, VA
# 10       Virginia                        Fairfax County, VA
# 11     California        Lancaster, CA (Los Angeles County)
# 12        Indiana         South Bend, IN (St Joseph County)
# 14   South Dakota              Yankton, SD (Yankton County)
# 15       Virginia  Colonial Beach, VA (Westmoreland County)
# 17       Delaware            Georgetown, DE (Sussex County)
# 18  Massachusetts                        Norfolk County, MA
# 19        Florida                 Perry, FL (Taylor County)
# 20       Maryland       Brownsville, MD (Washington County)
# 21        Florida             Miami, FL (Miami-Dade County)
# 22     New Jersey          Vineland, NJ (Cumberland County)
#
#                                             title_loc
# 0   Central New Jersey in Middlesex County, New Je...  \
# 1                            Mays Landing, New Jersey
# 3                            Pinellas County, Florida
# 4                                 Baltimore, Maryland
# 5                                     Casco, Michigan
# 6                              Fulton County, Georgia
# 7                                    Wister, Oklahoma
# 8                                  Quantico, Virginia
# 9                            Fairfax County, Virginia
# 10                           Fairfax County, Virginia
# 11                              Lancaster, California
# 12                                South Bend, Indiana
# 14               Yankton, SD in Yankton, South Dakota
# 15                           Colonial Beach, Virginia
# 17                               Georgetown, Delaware
# 18                      Norfolk County, Massachusetts
# 19               high traffic area! in Perry, Florida
# 20                  Maryland in Brownsville, Maryland
# 21                                     Miami, Florida
# 22                  busy area in Vineland, New Jersey
#
#                                            categories  ... franchise  lease
# 0   [Real Estate For Sale, New Jersey, Marinas and...  ...     False  False  \
# 1   [Real Estate For Sale, New Jersey, Other, Mays...  ...     False  False
# 3   [Real Estate For Sale, Florida, Other, Pinella...  ...     False  False
# 4   [Real Estate For Sale, Maryland, Bars, Pubs an...  ...     False  False
# 5   [Real Estate For Sale, Michigan, Convenience S...  ...     False  False
# 6   [Real Estate For Sale, Georgia, Liquor Stores,...  ...     False  False
# 7    [Real Estate For Sale, Oklahoma, Diners, Wister]  ...     False  False
# 8   [Real Estate For Sale, Virginia, American Rest...  ...     False  False
# 9   [Real Estate For Sale, Virginia, Auto Repair a...  ...     False  False
# 10  [Real Estate For Sale, Virginia, Auto Repair a...  ...     False  False
# 11  [Real Estate For Sale, California, Other, Lanc...  ...     False  False
# 12  [Real Estate For Sale, Indiana, Miscellaneous ...  ...     False  False
# 14  [Real Estate For Sale, South Dakota, Other, Ya...  ...     False  False
# 15  [Real Estate For Sale, Virginia, Marinas and F...  ...     False  False
# 17  [Real Estate For Sale, Delaware, Medical Pract...  ...     False  False
# 18  [Real Estate For Sale, Massachusetts, Bars, Pu...  ...     False  False
# 19      [Real Estate For Sale, Florida, Other, Perry]  ...     False  False
# 20  [Real Estate For Sale, Maryland, American Rest...  ...     False  False
# 21  [Real Estate For Sale, Florida, Dental Practic...  ...     False  False
# 22  [Real Estate For Sale, New Jersey, Hair Salons...  ...     False  False
#
#    auction   rent                                 _location nationwide
# 0    False  False                      Middlesex County, NJ      False  \
# 1    False  False        Mays Landing, NJ (Atlantic County)      False
# 3    False  False                       Pinellas County, FL      False
# 4    False  False     Baltimore, MD (Baltimore City County)      False
# 5    False  False            Casco, MI (Saint Clair County)      False
# 6    False  False                         Fulton County, GA      False
# 7    False  False               Wister, OK (LeFlore County)      False
# 8    False  False      Quantico, VA (Prince William County)      False
# 9    False  False                        Fairfax County, VA      False
# 10   False  False                        Fairfax County, VA      False
# 11   False  False        Lancaster, CA (Los Angeles County)      False
# 12   False  False         South Bend, IN (St Joseph County)      False
# 14   False  False              Yankton, SD (Yankton County)      False
# 15   False  False  Colonial Beach, VA (Westmoreland County)      False
# 17   False  False            Georgetown, DE (Sussex County)      False
# 18   False  False                        Norfolk County, MA      False
# 19   False  False                 Perry, FL (Taylor County)      False
# 20   False  False       Brownsville, MD (Washington County)      False
# 21   False  False             Miami, FL (Miami-Dade County)      False
# 22   False  False          Vineland, NJ (Cumberland County)      False
#
#    multiple_locations relocatable                                  proc_loc
# 0               False       False                      middlesex county, nj  \
# 1               False       False        mays landing, nj (atlantic county)
# 3               False       False                       pinellas county, fl
# 4               False       False     baltimore, md (baltimore city county)
# 5               False       False            casco, mi (saint clair county)
# 6               False       False                         fulton county, ga
# 7               False       False               wister, ok (leflore county)
# 8               False       False      quantico, va (prince william county)
# 9               False       False                        fairfax county, va
# 10              False       False                        fairfax county, va
# 11              False       False        lancaster, ca (los angeles county)
# 12              False       False         south bend, in (st joseph county)
# 14              False       False              yankton, sd (yankton county)
# 15              False       False  colonial beach, va (westmoreland county)
# 17              False       False            georgetown, de (sussex county)
# 18              False       False                        norfolk county, ma
# 19              False       False                 perry, fl (taylor county)
# 20              False       False       brownsville, md (washington county)
# 21              False       False             miami, fl (miami-dade county)
# 22              False       False          vineland, nj (cumberland county)
#
#                                              fuzz_loc
# 0   [(middlesex county, nj, 100), (middlesex, nj, ...
# 1   [(atlantic county, nj, 89), (harding county, n...
# 3   [(pinellas county, fl, 100), (pinellas, fl, 10...
# 4   [(baltimore, md, 83), (gem county, id, 82), (c...
# 5   [(saint clair county, mi, 100), (saint clair c...
# 6   [(fulton county, ga, 100), (fulton, ga, 100), ...
# 7   [(leflore county, ms, 88), (love, ok, 86), (le...
# 8   [(price county, wi, 87), (king william, va, 80...
# 9   [(fairfax county, va, 100), (fairfax, va, 100)...
# 10  [(fairfax county, va, 100), (fairfax, va, 100)...
# 11  [(los angeles county, ca, 90), (lancaster coun...
# 12  [(st. joseph, in, 92), (posey county, in, 87),...
# 14  [(yankton county, sd, 100), (yankton, sd, 100)...
# 15  [(westmoreland county, va, 100), (westmoreland...
# 17  [(georgetown, sc, 92), (sussex, nj, 89), (geor...
# 18  [(norfolk county, ma, 100), (norfolk, ma, 100)...
# 19  [(perry county, il, 93), (taylor, ky, 89), (pe...
# 20  [(washington county, md, 100), (washington, md...
# 21  [(miami-dade county, fl, 100), (miami-dade, fl...
# 22  [(cumberland county, nj, 100), (cumberland, nj...
#
# [20 rows x 24 columns]

# %% [markdown]
# # Final dataframe

# %%
df=df[['id','src','url','title',
            'desc','location','relocatable','categories','similar',
            'details','financials','price']]

# %%
df.head()
# Out:
#           id      src                                                url
# 0  2067319.0  details  https://www.bizbuysell.com/Business-Real-Estat...  \
# 1  1990890.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 3  2039720.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 4  1576680.0  details  https://www.bizbuysell.com/Business-Real-Estat...
# 5  2087638.0  details  https://www.bizbuysell.com/Business-Real-Estat...
#
#                                                title
# 0  Popular Marina in Central New Jersey in Middle...  \
# 1  High Exposure in Mays Landing, New Jersey - Bi...
# 3  Duplex, Short term or Long term in Pinellas Co...
# 4  Major Price Reduction Rest/Tavern/ 13,000sq. f...
# 5  Business & Real Estate in Casco, Michigan - Bi...
#
#                                                 desc
# 0  It is fully owned by a man and his wife since ...  \
# 1  AMAZING OPPORTUNITY! Priced to sell and ready ...
# 3  Rare Largo/Seminole area duplex centrally loca...
# 4  Price reduced to $850. 000 MAKE AN OFFER!!!!!!...
# 5  • The Business and the Real Estate are For Sal...
#
#                                 location  relocatable
# 0                   Middlesex County, NJ        False  \
# 1     Mays Landing, NJ (Atlantic County)        False
# 3                    Pinellas County, FL        False
# 4  Baltimore, MD (Baltimore City County)        False
# 5         Casco, MI (Saint Clair County)        False
#
#                                           categories
# 0  [Real Estate For Sale, New Jersey, Marinas and...  \
# 1  [Real Estate For Sale, New Jersey, Other, Mays...
# 3  [Real Estate For Sale, Florida, Other, Pinella...
# 4  [Real Estate For Sale, Maryland, Bars, Pubs an...
# 5  [Real Estate For Sale, Michigan, Convenience S...
#
#                        similar
# 0  [1864705, 2071534, 2057087]  \
# 1  [2075819, 1864705, 2071534]
# 3  [2035549, 2067510, 2054271]
# 4  [2082461, 2050777, 2043561]
# 5  [2063595, 2048305, 2069188]
#
#                                              details
# 0  Location:\nMiddlesex County, NJ\nType:\nOther ...  \
# 1  Location:\nMays Landing, NJ\nType:\nOffice\nBu...
# 3  Location:\nPinellas County, FL\nType:\nMulti-F...
# 4  Location:\nBaltimore, MD\nType:\nRetail\nBuild...
# 5  Location:\nCasco, MI\nType:\nMulti-Family\nBui...
#
#                                           financials      price
# 0  Asking Price:\n$2,500,000\n                   ...  2500000.0
# 1  Asking Price:\n$225,000\n                     ...   225000.0
# 3  Asking Price:\n$595,000\n                     ...   595000.0
# 4  Asking Price:\n$1,050,000\n                   ...  1050000.0
# 5  Asking Price:\n$699,900\n                     ...   699900.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37773 entries, 0 to 37743
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           37773 non-null  float64
#  1   src          37773 non-null  object
#  2   url          37773 non-null  object
#  3   title        37773 non-null  object
#  4   desc         37773 non-null  object
#  5   location     37713 non-null  object
#  6   relocatable  37773 non-null  bool
#  7   categories   37773 non-null  object
#  8   similar      37773 non-null  object
#  9   details      37773 non-null  object
#  10  financials   37773 non-null  object
#  11  price        37773 non-null  float64
# dtypes: bool(1), float64(2), object(9)
# memory usage: 3.5+ MB
